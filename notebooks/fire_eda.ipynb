# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ycode\OneDrive\Desktop\ClimaRisk\data\csvs\fire\fire.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4060 entries, 0 to 4059
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           4060 non-null   str
#  1   Region            4060 non-null   str
#  2   Cause             4060 non-null   str
#  3   year              4060 non-null   int64
#  4   month             4060 non-null   int64
#  5   fires_count       4060 non-null   int64
#  6   burned_area_ha    4060 non-null   int64
#  7   temperature_c     4060 non-null   int64
#  8   humidity_percent  4060 non-null   int64
#  9   wind_speed_kmh    4060 non-null   int64
# dtypes: int64(7), str(3)
# memory usage: 317.3 KB
# None

# %%
print(df.describe())
# Out:
#               year        month  fires_count  burned_area_ha  temperature_c  \
# count  4060.000000  4060.000000  4060.000000     4060.000000    4060.000000
# mean   1953.000000     7.515271   253.333990    50228.442857      32.036946
# std      41.862055     1.689354   143.526274    29510.610783       9.976450
# min    1881.000000     5.000000     5.000000      118.000000      15.000000
# 25%    1917.000000     6.000000   131.000000    23842.250000      23.000000
# 50%    1953.000000     8.000000   253.000000    50198.000000      32.000000
# 75%    1989.000000     9.000000   377.250000    76566.750000      40.000000
# max    2025.000000    10.000000   499.000000    99987.000000      49.000000
#
#        humidity_percent  wind_speed_kmh
# count       4060.000000     4060.000000
# mean          49.247783       35.777094
# std           26.088110       19.511724
# min            5.000000        2.000000
# 25%           27.000000       18.000000
# ...

# %%
print(df.head(2))
# Out:
#   Country   Region      Cause  year  month  fires_count  burned_area_ha  \
# 0  Turkey    Mugla  Lightning  1881      8          353           76920
# 1  Turkey  Antalya  Lightning  1881      7          154           64920
#
#    temperature_c  humidity_percent  wind_speed_kmh
# 0             33                91              25
# 1             38                34              39
